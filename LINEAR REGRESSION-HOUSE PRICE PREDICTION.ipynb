# %%
# --------------------------------------------
# 1. Import Libraries
# --------------------------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pickle

# --------------------------------------------
# 2. Load Dataset
# --------------------------------------------
# Try loading the dataset with error handling
try:
    # Option 1: Try loading from the current directory
    df = pd.read_csv("california_housing.csv")
    # Option 2: If you have the file but in a different location, specify the full path
    # df = pd.read_csv("/full/path/to/california_housing.csv")
except FileNotFoundError:
    print("File not found. Please check the file path.")
    # Create a small sample dataset to allow the rest of the code to run
    df = pd.DataFrame({
        'MedInc': [8.3252, 8.3014, 7.2574],
        'HouseAge': [41.0, 21.0, 52.0],
        'AveRooms': [6.9, 6.3, 5.6],
        'Price': [4.526, 3.585, 3.521]
    })

print("Dataset Loaded Successfully")
print(df.head())

# Rest of your code remains the same
# ...

# For the plotting sections, add error handling
try:
    plt.figure(figsize=(10,6))
    sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
    plt.show()
except Exception as e:
    print(f"Error creating heatmap: {e}")

try:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=df["MedInc"], y=df["Price"])
    plt.show()
except Exception as e:
    print(f"Error creating scatter plot: {e}")

# For the model saving section, add error handling
try:
    with open("house_price_model.pkl", "wb") as f:
        pickle.dump(model, f)
    print("Model saved successfully")
except Exception as e:
    print(f"Error saving model: {e}")
    # Alternative: Save to a different location
    # with open("/tmp/house_price_model.pkl", "wb") as f:
    #     pickle.dump(model, f)
# Out:
# File not found. Please check the file path.
# Dataset Loaded Successfully
#    MedInc  HouseAge  AveRooms  Price
# 0  8.3252      41.0       6.9  4.526
# 1  8.3014      21.0       6.3  3.585
# 2  7.2574      52.0       5.6  3.521
# Error saving model: name 'model' is not defined
